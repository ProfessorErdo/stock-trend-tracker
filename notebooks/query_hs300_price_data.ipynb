# %%
import akshare as ak 

import pandas as pd
import numpy as np

import os 
from datetime import datetime
from tqdm import tqdm

# %%
# load the data
hs = pd.read_csv('../data/input/hs300_list_20251213.csv')
hs['code'] = hs['code'].astype(str).str.zfill(6)

STOCK_CODES = hs['code'].tolist()
print(len(STOCK_CODES))
# Out:
# 300

# %%
today = pd.to_datetime("today").strftime("%Y%m%d")

os.makedirs(f"../data/input/price-data/{today}", exist_ok=True)

# %%
stocks = os.listdir(f'../data/input/price-data/{today}/')
loaded_stocks = [stock[13:19] for stock in stocks]
len(loaded_stocks) 
MISSED_CODE= list(set(STOCK_CODES) - set(loaded_stocks)) 
len(MISSED_CODE)
# Out:
# 300

# %%
STOCK_SYMBOLS_1 = ["sh" + code if code.startswith("6") else "sz" + code for code in MISSED_CODE]
len(STOCK_SYMBOLS_1)
# Out:
# 300

# %%
today = pd.to_datetime("today").strftime("%Y%m%d")

while len(STOCK_SYMBOLS_1) > 0:
    print(len(STOCK_SYMBOLS_1))
    for symbol in tqdm(STOCK_SYMBOLS_1):
        try:
            price_df = ak.stock_zh_a_daily(symbol=f"{symbol}", start_date="20101231", end_date="20251231", adjust="")
            price_df = price_df[['date', 'open', 'high', 'low', 'close']]
            price_df.columns = ['report_date', 'open', 'high', 'low', 'close']
            price_df.to_csv(f"../data/input/price-data/{today}/price_data_{symbol}_{today}.csv", index=False)
            STOCK_SYMBOLS_1.remove(symbol)
        except: 
            continue
# Out:
# 300
#  51%|█████▏    | 154/300 [56:19<53:23, 21.94s/it]
# 154
#  51%|█████     | 78/154 [04:35<04:28,  3.53s/it]
# 77
#  51%|█████     | 39/77 [01:54<01:51,  2.95s/it]
# 38
#  50%|█████     | 19/38 [01:07<01:07,  3.55s/it]
# 19
#  53%|█████▎    | 10/19 [00:36<00:33,  3.68s/it]
# 9
#  56%|█████▌    | 5/9 [00:17<00:13,  3.43s/it]
# 4
#  50%|█████     | 2/4 [00:07<00:07,  3.78s/it]
# 2
#  50%|█████     | 1/2 [00:03<00:03,  3.53s/it]
# 1
# 100%|██████████| 1/1 [00:03<00:00,  3.10s/it]
